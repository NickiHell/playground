# %%
# Python. К вершинам мастерства Лучано Ромальо

# %%
import collections
import random

Card = collections.namedtuple('Card', ['rank', 'suits'])

class FrenchDeck:
    ranks = [str(n) for n in range(2, 11)] + list('JKQA')
    suits = 'spades diamonds clubs hearts'.split()

    def __init__(self):
        self._cards = [Card(rank, suit) for suit in self.suits for rank in self.ranks]
    def __len__(self):
        return len(self._cards)
    def __getitem__(self, position):
     return self._cards[position]
    
beer_card = Card('7', 'diamons')
print(beer_card)
deck = FrenchDeck()
print(len(deck))
print(deck[0])
print(random.choice(deck))
print(deck[:3])
for card in deck:
    print(card)
for card in reversed(deck):
    print(card)
suit_values = dict(spades=3, hearts=2, diamonds=1, clubs=0)
def spades_high(card):
    rank_value = FrenchDeck.ranks.index(card.rank)
    return rank_value * len(suit_values) + suit_values[card.suits]
for card in sorted(deck, key=spades_high):
    print(card)

# %%
import math
class Vector:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y
        
    def __repr__(self):
        return f'Vector({self.x!r}, {self.y!r})'
    
    def __abs__(self):
        return math.hypot(self.x, self.y)
    
    def __bool__(self):
        return bool(abs(self))
    
    def __add__(self, other):
        x = self.x + other.x
        y = self.y + other.y
        return Vector(x, y)
    
    def __mul__(self, scalar):
        return Vector(self.x * scalar, self.y * scalar)
    
    
v1 = Vector(2, 4)
v2 = Vector(2, 1)
print(v1 + v2)

v = Vector(3, 4)
assert abs(v) == 5.0
assert abs(v * 3) == 15.0

# %%
pip install speakerpy
# Out:
# Requirement already satisfied: speakerpy in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (3.8.1)
# Requirement already satisfied: num2words<0.6.0,>=0.5.12 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (0.5.13)
# Requirement already satisfied: numpy<2.0.0,>=1.24.2 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (1.26.0)
# Requirement already satisfied: pydub<0.26.0,>=0.25.1 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (0.25.1)
# Requirement already satisfied: silero<0.5.0,>=0.4.1 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (0.4.1)
# Requirement already satisfied: sounddevice<0.5.0,>=0.4.6 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (0.4.6)
# Requirement already satisfied: soundfile<0.13.0,>=0.12.1 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (0.12.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (4.66.1)
# Requirement already satisfied: transliterate<2.0.0,>=1.10.2 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from speakerpy) (1.10.2)
# Requirement already satisfied: click in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->speakerpy) (8.1.7)
# Requirement already satisfied: joblib in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->speakerpy) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->speakerpy) (2023.10.3)
# Requirement already satisfied: docopt>=0.6.2 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from num2words<0.6.0,>=0.5.12->speakerpy) (0.6.2)
# Requirement already satisfied: torch>=1.10.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from silero<0.5.0,>=0.4.1->speakerpy) (2.1.1)
# Requirement already satisfied: torchaudio>=0.10.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from silero<0.5.0,>=0.4.1->speakerpy) (2.1.1)
# Requirement already satisfied: omegaconf>=2.1.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from silero<0.5.0,>=0.4.1->speakerpy) (2.3.0)
# Requirement already satisfied: CFFI>=1.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from sounddevice<0.5.0,>=0.4.6->speakerpy) (1.16.0)
# Requirement already satisfied: six>=1.1.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from transliterate<2.0.0,>=1.10.2->speakerpy) (1.16.0)
# Requirement already satisfied: pycparser in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from CFFI>=1.0->sounddevice<0.5.0,>=0.4.6->speakerpy) (2.21)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from omegaconf>=2.1.0->silero<0.5.0,>=0.4.1->speakerpy) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from omegaconf>=2.1.0->silero<0.5.0,>=0.4.1->speakerpy) (6.0.1)
# Requirement already satisfied: filelock in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (4.8.0)
# Requirement already satisfied: sympy in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (1.12)
# Requirement already satisfied: networkx in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (3.2.1)
# Requirement already satisfied: jinja2 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (3.1.2)
# Requirement already satisfied: fsspec in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (2023.12.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/nickihell/.virtualenvs/playground/lib/python3.10/site-packages (from sympy->torch>=1.10.0->silero<0.5.0,>=0.4.1->speakerpy) (1.3.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: /home/nickihell/.virtualenvs/playground/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from lib_speak import Speaker
from lib_sl_text import SeleroText

text = SeleroText("Пример текста для синтеза речи")
speaker = Speaker(model_id="ru_v3", language="ru", speaker="aidar", device="cpu")
speaker.speak(text=text, sample_rate=48000, speed=1.0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from lib_speak import Speaker
#       2 from lib_sl_text import SeleroText
#       4 text = SeleroText("Пример текста для синтеза речи")
#
# ModuleNotFoundError: No module named 'lib_speak'

# %%
import torch

model, example_text = torch.hub.load(repo_or_dir='Daswer123/xtts_warcraft3_ru',
                                     model='silero_tts',
                                     language='ru',
                                     speaker=model_id)
model.to('cpu')  # gpu or cpu

audio = model.apply_tts(text=example_text,
                        speaker=speaker,
                        sample_rate=sample_rate)

# %%
import functools

@functools.lru_cache(maxsize=100, typed=False)
def fib(x: int) -> int:
    if x in [1, 2]:
        return 1
    else:
        return fib(x - 1) + fib(x - 2)
    
print(fib(50))  
print(fib(100))
# Out:
# 12586269025
# 354224848179261915075
